# %%
# Secuencia de escape
print("primera linea\nsegunda linea")
# Out:
# primera linea
# segunda linea

# %%
# Tabulacion
print("Nombre:\tCarlos")
print("Edad:\t39")
# Out:
# Nombre:	Carlos
# Edad:	39

# %%
print("Carpeta: C:\\Usuarios\\Carlos")
# Out:
# Carpeta: C:\Usuarios\Carlos

# %% [markdown]
# ## Strings
# Cadenas de texto

# %%
print(450+150)
# Out:
# 600

# %%
print("Hola" + "Carlos")
print("Hola " + "Carlos")
print("Hola" + " " + "Carlos")
# Out:
# HolaCarlos
# Hola Carlos
# Hola Carlos

# %%
print("Esta es la primera linea\nEsta es la segunda linea")
# Out:
# Esta es la primera linea
# Esta es la segunda linea

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('A\tB\tC\nD\tE\tF\nG\tH\tI')
# Out:
# A	B	C
# D	E	F
# G	H	I

# %%
print('Barra Normal: /')
print('Barra Invertida: \\')
# Out:
# Barra Normal: /
# Barra Invertida: \

# %%
# El texto tiene comillas simples → usa dobles afuera
print("Él dijo 'hola' y se fue")

# El texto tiene comillas dobles → usa simples afuera
print('Ella respondió "adiós"')

# O usa la barra invertida para "escapar" la comilla
print("Él dijo \"hola\" y se fue")
# Out:
# Él dijo 'hola' y se fue
# Ella respondió "adiós"
# Él dijo "hola" y se fue

# %%
print("Ja" * 3)

print("=" * 20)

print("-*" * 10)

# Útil para crear separadores
print("TÍTULO")
print("─" * 15)
# Out:
# JaJaJa
# ====================
# -*-*-*-*-*-*-*-*-*-*
# TÍTULO
# ───────────────

# %%
# Desde índice 0 hasta índice 3 (sin incluir el 3)
print("Python"[0:3])

# Desde índice 2 hasta índice 5
print("Python"[2:5])

# Desde el inicio hasta índice 4
print("Python"[:4])

# Desde índice 2 hasta el final
print("Python"[2:])
# Out:
# Pyt
# tho
# Pyth
# thon

# %%
# Extraer extensión de archivo
print("documento.pdf"[-3:])

# Extraer código de país
print("+54 11 1234-5678"[:3])

# Extraer las primeras 5 letras
print("Bienvenidos al curso"[:5])
# Out:
# pdf
# +54
# Bienv

# %%
print("Tu nombre es " + (input("Dime tu nombre: ")) + " y tu apellido es " + (input("Dime tu apellido: ")))
# Out:
# Tu nombre es Carlosy tu apellido es Garcia

# %%
print("=== CALCULADORA ===")
print("Resultado: ", float(input("Primer número: ")) + float(input("Segundo número: ")))
# Out:
# === CALCULADORA ===
# Resultado:  119.0

# %%
# Calcular la edad
print("Tu edad es:", 2025 - int(input("¿En qué año naciste? ")))
# Out:
# Tu edad es: 39

# %% [markdown]
# # Proyecto del día 1

# %%
palabra1 = input("ingresa un animal de una palabra: ")
palabra2 = input("Ingresa un elemento ")
marca = palabra1[:-3] + palabra2[3:]
print(marca)
# Out:
# leopanto
